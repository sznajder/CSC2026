# %% [markdown]
# <a href="https://colab.research.google.com/github/INCT-CERN-Brasil/Escola2024/blob/main/Sznajder/JetTagging_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training a Jet Tagging **DeepSets**
#
# ---
# In this notebook, we perform a Jet identification task using a DeepSets multiclass classifier.
# The problem consists in identifying a given jet as a quark, a gluon, a W, a Z, or a top.
# We will represent each jet as a point cloud (or a "particle cloud") which consiststs of unordered set of jet's consistuent particles. Such a particle cloud representation of jets is efficient in incorporating raw information of jets and also explicitly respects the permutation symmetry.
#
# Based on https://github.com/jngadiub/ML_course_Pavia_23
#
# Modified by: Andre Sznajder
#
# ---

# %%
import os
import h5py
import glob, pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Preparation of the training and validation samples
#
# ---
# In order to import the dataset, we now
# - clone the dataset repository (to import the data in Colab)
# - load the h5 files in the data/ repository
# - extract the data we need: a target and jetImage
#
# To type shell commands, we start the command line with !
#
# **nb, if you are running locally and you have already downloaded the datasets you can skip the cell below and, if needed, change the paths later to point to the folder with your previous download of the datasets.**

# %%
if not os.path.exists("Data-MLtutorial/JetDataset"):
    print("Dataset not found locally. Downloading and extracting...")
    os.system("curl -L https://cernbox.cern.ch/s/Hixs6KpgPFH8MN9/download -o Data-MLtutorial.tar.gz")
    os.system("tar -zxvf Data-MLtutorial.tar.gz")
    os.remove("Data-MLtutorial.tar.gz")
else:
    print("Dataset already exists. Skipping download.")

os.system("ls -al Data-MLtutorial/JetDataset/")

# %%
target = np.array([])
jetList = np.array([])
feat_names = dict()
# we cannot load all data on Colab. So we just take a few files
datafiles = ['Data-MLtutorial/JetDataset/jetImage_7_100p_30000_40000.h5',
             'Data-MLtutorial/JetDataset/jetImage_7_100p_60000_70000.h5',
             'Data-MLtutorial/JetDataset/jetImage_7_100p_50000_60000.h5',
             'Data-MLtutorial/JetDataset/jetImage_7_100p_10000_20000.h5',
             'Data-MLtutorial/JetDataset/jetImage_7_100p_0_10000.h5']
# if you are running locallt, you can use the full dataset doing
# for fileIN in glob.glob("tutorials/HiggsSchool/data/*h5"):
first=0
for fileIN in datafiles:
    print("Appending %s" %fileIN)
    f = h5py.File(fileIN)
    myJetList = np.array(f.get("jetConstituentList"))
    mytarget = np.array(f.get('jets')[0:,-6:-1])
    jetList = np.concatenate([jetList, myJetList], axis=0) if jetList.size else myJetList
    target = np.concatenate([target, mytarget], axis=0) if target.size else mytarget
    #save particles/nodes features names and their indecies in a dictionary
    if first==0:
      for feat_idx,feat_name in enumerate(list(f['particleFeatureNames'])[:-1]):
        feat_names[feat_name.decode("utf-8").replace('j1_','')] = feat_idx
      first=1
    del myJetList, mytarget
    f.close()
print(target.shape, jetList.shape)
# Out:
# Appending Data-MLtutorial/JetDataset/jetImage_7_100p_30000_40000.h5
# Appending Data-MLtutorial/JetDataset/jetImage_7_100p_60000_70000.h5
# Appending Data-MLtutorial/JetDataset/jetImage_7_100p_50000_60000.h5
# Appending Data-MLtutorial/JetDataset/jetImage_7_100p_10000_20000.h5
# Appending Data-MLtutorial/JetDataset/jetImage_7_100p_0_10000.h5
# (50000, 5) (50000, 100, 16)

# %% [markdown]
# ## One-Hot Encoding
#
# The ground truth is incorporated in the ['j_g', 'j_q', 'j_w', 'j_z', 'j_t] vector of boolean, taking the form
# *  [1, 0, 0, 0, 0] for gluons
# *  [0, 1, 0, 0, 0] for quarks
# *  [0, 0, 1, 0, 0] for W
# *  [0, 0, 0, 1, 0] for Z
# *  [0, 0, 0, 0, 1] for top quarks
#
# This is what is called 'one-hot' encoding of a descrete label (typical of ground truth for classification problems). These labels are the 'target' for our classification tasks. Let's convert it back to single-column encoding :

# %%
num_classes = len(np.unique(target))
label_names= ["gluon", "quark", "W", "Z", "top"]

# %% [markdown]
# ## Jet Constituents features

# %%
feat_to_consider = 'etarel,phirel,pt,e,ptrel,erel,deltaR'.split(',')
feat_idx = [feat_names[name] for name in feat_to_consider]
jetList = jetList[:,:,feat_idx]
print('Particles/Nodes considered features : ',feat_to_consider)
# Out:
# Particles/Nodes considered features :  ['etarel', 'phirel', 'pt', 'e', 'ptrel', 'erel', 'deltaR']

# %% [markdown]
# ## Prepare the train and test datasets

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(jetList, target, test_size=0.33)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
print('Jets shape : ',jetList.shape)
print('Target/Labels shape : ',target.shape)
del jetList, target
# Out:
# (33500, 100, 7) (16500, 100, 7) (33500, 5) (16500, 5)
# Jets shape :  (50000, 100, 7)
# Target/Labels shape :  (50000, 5)

# %%
# keras imports
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten
from tensorflow.keras.layers import GlobalAveragePooling1D, BatchNormalization, Activation
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN

# %%
nnodes_phi = 32
nnodes_rho = 16
activ      = "relu"

# Input tensor shape
nconstit = X_train.shape[1]
nfeat = X_train.shape[2]


# Instantiate Tensorflow input tensors in Batch mode
inp = Input(shape=(nconstit,nfeat), name="inp")   # Conv1D input format


# Input point features BatchNormalization
h = BatchNormalization(name='BatchNorm')(inp)

# Phi MLP ( permutation equivariant layers )
h = Dense(nnodes_phi)(h)
h = Activation(activ)(h)
h = Dense(nnodes_phi)(h)
h = Activation(activ)(h)
h = Dense(nnodes_phi)(h)
phi_out = Activation(activ)(h)


# Agregate features (taking mean) over set elements
mean = GlobalAveragePooling1D(name='avgpool_1')(phi_out)      # return mean of features over jets constituents

# Rho MLP
h = Dense(nnodes_rho)(mean)
h = Activation(activ)(h)
h = Dense(num_classes)(h)
out = Activation('softmax',name='softmax_g')(h)

# Build the model
model = Model(inputs=inp, outputs=out)
# Out:
# Metal device set to: Apple M1

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[metrics.CategoricalAccuracy()])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inp (InputLayer)            [(None, 100, 7)]          0
#
#  BatchNorm (BatchNormalizati  (None, 100, 7)           28
#  on)
#
#  dense (Dense)               (None, 100, 32)           256
#
#  activation (Activation)     (None, 100, 32)           0
#
#  dense_1 (Dense)             (None, 100, 32)           1056
#
#  activation_1 (Activation)   (None, 100, 32)           0
#
#  dense_2 (Dense)             (None, 100, 32)           1056
#
#  activation_2 (Activation)   (None, 100, 32)           0
#
#  avgpool_1 (GlobalAveragePoo  (None, 32)               0
#  ling1D)
#
#  dense_3 (Dense)             (None, 16)                528
#
#  activation_3 (Activation)   (None, 16)                0
#
#  dense_4 (Dense)             (None, 5)                 85
#
#  softmax_g (Activation)      (None, 5)                 0
#
# =================================================================
# Total params: 3,009
# Trainable params: 2,995
# Non-trainable params: 14
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
batch_size = 128
epochs = 50

history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/50
# 2024-11-08 17:54:02.379000: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 236/236 [==============================] - 6s 24ms/step - loss: 1.3973 - categorical_accuracy: 0.3805 - val_loss: 1.4305 - val_categorical_accuracy: 0.3057
# Epoch 2/50
# 236/236 [==============================] - 5s 22ms/step - loss: 1.1396 - categorical_accuracy: 0.5359 - val_loss: 1.1043 - val_categorical_accuracy: 0.5663
# Epoch 3/50
# 236/236 [==============================] - 6s 25ms/step - loss: 1.0095 - categorical_accuracy: 0.5890 - val_loss: 0.9972 - val_categorical_accuracy: 0.6018
# Epoch 4/50
# 236/236 [==============================] - 6s 25ms/step - loss: 0.9728 - categorical_accuracy: 0.6110 - val_loss: 0.9613 - val_categorical_accuracy: 0.6266
# Epoch 5/50
# 236/236 [==============================] - 5s 22ms/step - loss: 0.9477 - categorical_accuracy: 0.6284 - val_loss: 0.9402 - val_categorical_accuracy: 0.6421
# Epoch 6/50
# 236/236 [==============================] - 5s 22ms/step - loss: 0.9342 - categorical_accuracy: 0.6371 - val_loss: 0.9342 - val_categorical_accuracy: 0.6451
# Epoch 7/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.9186 - categorical_accuracy: 0.6452 - val_loss: 0.9174 - val_categorical_accuracy: 0.6573
# Epoch 8/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.9093 - categorical_accuracy: 0.6489 - val_loss: 0.8972 - val_categorical_accuracy: 0.6684
# Epoch 9/50
# 236/236 [==============================] - 7s 28ms/step - loss: 0.8996 - categorical_accuracy: 0.6554 - val_loss: 0.9028 - val_categorical_accuracy: 0.6606
# Epoch 10/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8950 - categorical_accuracy: 0.6567 - val_loss: 0.9033 - val_categorical_accuracy: 0.6651
# Epoch 11/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8941 - categorical_accuracy: 0.6580 - val_loss: 0.8764 - val_categorical_accuracy: 0.6710
# Epoch 12/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8847 - categorical_accuracy: 0.6642 - val_loss: 0.9110 - val_categorical_accuracy: 0.6349
# Epoch 13/50
# 236/236 [==============================] - 6s 24ms/step - loss: 0.8825 - categorical_accuracy: 0.6629 - val_loss: 0.8738 - val_categorical_accuracy: 0.6764
# Epoch 14/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8726 - categorical_accuracy: 0.6701 - val_loss: 0.8667 - val_categorical_accuracy: 0.6830
# Epoch 15/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8679 - categorical_accuracy: 0.6718 - val_loss: 0.8709 - val_categorical_accuracy: 0.6896
# Epoch 16/50
# 236/236 [==============================] - 7s 28ms/step - loss: 0.8662 - categorical_accuracy: 0.6714 - val_loss: 0.8584 - val_categorical_accuracy: 0.6830
# Epoch 17/50
# 236/236 [==============================] - 6s 26ms/step - loss: 0.8540 - categorical_accuracy: 0.6816 - val_loss: 0.8513 - val_categorical_accuracy: 0.6925
# Epoch 18/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8533 - categorical_accuracy: 0.6818 - val_loss: 0.8494 - val_categorical_accuracy: 0.6958
# Epoch 19/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8510 - categorical_accuracy: 0.6808 - val_loss: 0.8433 - val_categorical_accuracy: 0.7030
# Epoch 20/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8498 - categorical_accuracy: 0.6823 - val_loss: 0.8347 - val_categorical_accuracy: 0.7069
# Epoch 21/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8473 - categorical_accuracy: 0.6850 - val_loss: 0.8336 - val_categorical_accuracy: 0.7060
# Epoch 22/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8434 - categorical_accuracy: 0.6856 - val_loss: 0.8240 - val_categorical_accuracy: 0.7096
# Epoch 23/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8365 - categorical_accuracy: 0.6920 - val_loss: 0.8255 - val_categorical_accuracy: 0.7104
# Epoch 24/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8353 - categorical_accuracy: 0.6897 - val_loss: 0.8179 - val_categorical_accuracy: 0.7185
# Epoch 25/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8277 - categorical_accuracy: 0.6940 - val_loss: 0.8165 - val_categorical_accuracy: 0.7116
# Epoch 26/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8232 - categorical_accuracy: 0.6971 - val_loss: 0.8161 - val_categorical_accuracy: 0.7218
# Epoch 27/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8241 - categorical_accuracy: 0.6939 - val_loss: 0.8052 - val_categorical_accuracy: 0.7266
# Epoch 28/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8144 - categorical_accuracy: 0.7043 - val_loss: 0.7985 - val_categorical_accuracy: 0.7212
# Epoch 29/50
# 236/236 [==============================] - 6s 24ms/step - loss: 0.8092 - categorical_accuracy: 0.7031 - val_loss: 0.7993 - val_categorical_accuracy: 0.7182
# Epoch 30/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8037 - categorical_accuracy: 0.7076 - val_loss: 0.7975 - val_categorical_accuracy: 0.7194
# Epoch 31/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8060 - categorical_accuracy: 0.7050 - val_loss: 0.7813 - val_categorical_accuracy: 0.7385
# Epoch 32/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.8034 - categorical_accuracy: 0.7061 - val_loss: 0.7808 - val_categorical_accuracy: 0.7364
# Epoch 33/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7967 - categorical_accuracy: 0.7109 - val_loss: 0.7835 - val_categorical_accuracy: 0.7370
# Epoch 34/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7891 - categorical_accuracy: 0.7151 - val_loss: 0.7918 - val_categorical_accuracy: 0.7281
# Epoch 35/50
# 236/236 [==============================] - 6s 23ms/step - loss: 0.7916 - categorical_accuracy: 0.7134 - val_loss: 0.7703 - val_categorical_accuracy: 0.7403
# Epoch 36/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7901 - categorical_accuracy: 0.7151 - val_loss: 0.7684 - val_categorical_accuracy: 0.7513
# Epoch 37/50
# 236/236 [==============================] - 6s 23ms/step - loss: 0.7850 - categorical_accuracy: 0.7147 - val_loss: 0.7607 - val_categorical_accuracy: 0.7501
# Epoch 38/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7808 - categorical_accuracy: 0.7176 - val_loss: 0.7673 - val_categorical_accuracy: 0.7328
# Epoch 39/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7811 - categorical_accuracy: 0.7207 - val_loss: 0.7770 - val_categorical_accuracy: 0.7218
# Epoch 40/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7748 - categorical_accuracy: 0.7215 - val_loss: 0.7637 - val_categorical_accuracy: 0.7433
# Epoch 41/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7738 - categorical_accuracy: 0.7227 - val_loss: 0.7428 - val_categorical_accuracy: 0.7600
# Epoch 42/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7723 - categorical_accuracy: 0.7228 - val_loss: 0.7459 - val_categorical_accuracy: 0.7487
# Epoch 43/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7754 - categorical_accuracy: 0.7203 - val_loss: 0.7421 - val_categorical_accuracy: 0.7558
# Epoch 44/50
# 236/236 [==============================] - 6s 23ms/step - loss: 0.7694 - categorical_accuracy: 0.7245 - val_loss: 0.7488 - val_categorical_accuracy: 0.7451
# Epoch 45/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7654 - categorical_accuracy: 0.7286 - val_loss: 0.7272 - val_categorical_accuracy: 0.7666
# Epoch 46/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7643 - categorical_accuracy: 0.7275 - val_loss: 0.7286 - val_categorical_accuracy: 0.7567
# Epoch 47/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7568 - categorical_accuracy: 0.7335 - val_loss: 0.7286 - val_categorical_accuracy: 0.7612
# Epoch 48/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7511 - categorical_accuracy: 0.7343 - val_loss: 0.7291 - val_categorical_accuracy: 0.7552
# Epoch 49/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7604 - categorical_accuracy: 0.7282 - val_loss: 0.7217 - val_categorical_accuracy: 0.7675
# Epoch 50/50
# 236/236 [==============================] - 5s 23ms/step - loss: 0.7443 - categorical_accuracy: 0.7359 - val_loss: 0.7158 - val_categorical_accuracy: 0.7687

# %%
fig,axes = plt.subplots(2)
print(history.history.keys())
axes[0].plot(history.history["categorical_accuracy"])
axes[0].plot(history.history["val_categorical_accuracy"])
axes[0].set_title("Accuracy")
axes[0].legend(["Training", "Validation"])

axes[1].plot(history.history["loss"])
axes[1].plot(history.history["val_loss"])
axes[1].legend(["Training", "Validation"])
axes[1].set_title("Loss")

fig.show()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])
# /var/folders/4k/3rlblhv55d10vc6y4lnyb0v40000gn/T/ipykernel_10339/870046722.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # Building the ROC Curves

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_curve, auc
predict_val = model.predict(X_val)
df = pd.DataFrame()
fpr = {}
tpr = {}
auc1 = {}

plt.figure()
for i, label in enumerate(label_names):

        df[label] = y_val[:,i]
        df[label + '_pred'] = predict_val[:,i]

        fpr[label], tpr[label], threshold = roc_curve(df[label],df[label+'_pred'])

        auc1[label] = auc(fpr[label], tpr[label])

        plt.plot(tpr[label],fpr[label],label='%s tagger, auc = %.1f%%'%(label,auc1[label]*100.))
plt.semilogy()
plt.xlabel("sig. efficiency")
plt.ylabel("bkg. mistag rate")
plt.ylim(0.000001,1)
plt.grid(True)
plt.legend(loc='lower right')
plt.show()
